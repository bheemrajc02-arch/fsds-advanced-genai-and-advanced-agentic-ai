# %%
#Numpy 
# numpy is a very powerful library used for business analysis and data anlysis
# data analysis
# business analysis
# machine learning
# artificial intelligence
# computer vision
# rnn concept
# lstm
# speech recognition
# generative ai
# predictive model
#===================================
# 1d array vs 2d array vs 3d array vs nd array

# Numpy -- Numpy is the library which handles multidimensional arrays (nd array)
# n number of rows
# n number of columns

# --- Examples of NumPy Arrays ---

# 1D Array (Vector)
# A single row of elements.
# Example: import numpy as np; arr_1d = np.array([1, 2, 3, 4])

# 2D Array (Matrix)
# Structured with rows and columns (like a table).
# Example: arr_2d = np.array([[1, 2, 3], [4, 5, 6]])

# 3D Array (Tensor / Cube)
# An array of 2D matrices (adds depth, like a stack of papers or RGB image channels).
# Example: arr_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])

# ND Array (N-Dimensional Array)
# Any generic array with 'n' dimensions managed natively by NumPy.

# Using the numpy one can perform arithemetic operations 
# Using the numpy one can perform Statistical operations 
# Using the numpy one can perform bitwise operations 
# Using the numpy one can perform copying and view array
# Using the numpy one can perform metrix operations and linear algebra
# Using the numpy one can perform broadcasting and math operations
# Using the numpy one can perform searching, sorting and counting
# --- Image to Array Conversion ---

# How it works:
# An image is essentially a grid of pixels. 
# A Grayscale (black and white) image is converted into a 2D array (height x width).
# A Color (RGB) image is converted into a 3D array (height x width x 3 color channels: Red, Green, Blue).

# 

# --- Example using Python (PIL and NumPy) ---

# Step 1: Import the required libraries
# import numpy as np
# from PIL import Image

# Step 2: Load your image file
# img = Image.open('your_image.jpg')

# Step 3: Convert the image into a NumPy ND-Array
# img_array = np.array(img)

# --- Conceptual Representation of the Resulting Array ---

# For a tiny 3x3 pixel COLOR image, the resulting 3D array looks like this:
# Each pixel has 3 values representing [Red, Green, Blue] intensity from 0 to 255.

# img_array = np.array([
#     [[255,   0,   0], [  0, 255,   0], [  0,   0, 255]],  # Row 1: Red, Green, Blue pixels
#     [[  0,   0,   0], [255, 255, 255], [128, 128, 128]],  # Row 2: Black, White, Gray pixels
#     [[255, 255,   0], [  0, 255, 255], [255,   0, 255]]   # Row 3: Yellow, Cyan, Magenta pixels
# ])

# Checking the structural properties of your image array:
# print(img_array.shape)  # Output would be (3, 3, 3) representing (height, width, channels)
# print(img_array.ndim)   # Output would be 3 (since it is a 3D array)

# %%
import numpy as np

# %%
np.__version__

# %%
my_list = [0,1,2,3,4,5]
my_list

# %%
type(my_list)

# %%
arr = np.array(my_list)
arr

# %%
print(type(my_list))
print(type(arr))

# %%
np.arange(10)

# %%
np.arange(10,20)       # formaula  is N-1 right is always applied n-1

# %%
np.arange(10,50,5)       # max we can pass 3 arguments

# %%
np.arange(20,10)      # This is array not list 
                       # Note : In arrange function first argument is always less then 2nd argument

# %%
np.arange(-20,10)

# %%
np.zeros(3)           # 2d array

# %%
np.zeros(3,dtype=int)   # This is called hyper parameter tuning

# %%
np.zeros([2,2])       # 2 dimentioanl array

# %%
np.zeros([10,10], dtype=int)

# %%
np.ones(4)

# %%
np.ones(4,dtype=int)

# %%
np.ones(4,dtype=float)

# %%
np.random.rand(3)
