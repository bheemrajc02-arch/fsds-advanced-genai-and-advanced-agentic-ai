# %%
s = welcome
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s = welcome
#
# NameError: name 'welcome' is not defined

# %%
True
# Out:
# True

# %%
s = 'Welcome'
print(s)
# Out:
# Welcome

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
id(s)       # id means Address where the string stored that address the address of memory location
# Out:
# 2317806585520

# %%
s
# Out:
# 'Welcome'

# %%
len(s)         # Length of String   starts with index 0
# Out:
# 7

# %%
s1 =  "welcome to nit"    # doble quote
s1
id(s1)
# Out:
# 2317806730864

# %%
s2 = '''Welcome 
        to                                   
        nit technology'''                       # single quote 
s2
# Out:
# 'Welcome \n        to \n        nit technology'

# %%
id(s1)
id(s2)
# Out:
# 2317802023696

# %%
s3 = "welcome to nit" 
s4 = "welcome to nit" 
print(s3)
print(s4)
print("Address of s3 " +id(s3))
print("Address of s4 " +id(s4))
# Out:
# welcome to nit
# welcome to nit
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3 print(s3)
#       4 print(s4)
# ----> 5 print("Address of s3 " +id(s3))
#       6 print("Address of s4 " +id(s4))
#
# TypeError: can only concatenate str (not "int") to str

# %%
s3 = "welcome to nit" 
s4 = "welcome to nit" 

print(s3)
print(s4)

# Using f-strings automatically handles the conversion
print(f"Address of s3 {id(s3)}")
print(f"Address of s4 {id(s4)}")
# Out:
# welcome to nit
# welcome to nit
# Address of s3 2317806978736
# Address of s4 2317806979184

# %%
s3 = "welcome to nit" 
s4 = "welcome to nit" 

print(s3)
print(s4)

# Explicitly converting the integer ID to a string
print("Address of s3 " + str(id(s3)))
print("Address of s4 " + str(id(s4)))
# Out:
# welcome to nit
# welcome to nit
# Address of s3 2317806893296
# Address of s4 2317806894448

# %%
s5 = "welcome" 
s6 = "welcome" 

print(s5)
print(s6)

# Explicitly converting the integer ID to a string
print("Address of s3 " + str(id(s5)))
print("Address of s4 " + str(id(s6)))
# Out:
# welcome
# welcome
# Address of s3 2317785229232
# Address of s4 2317785229232

# %%
# Python indexing 
# Forward indexing  -------------------->Left to Right 
# Backward indexing -------------------->Right to left

s
# Out:
# 'Welcome'

# %%
s[0]   # Forward index
# Out:
# 'W'

# %%
s[6]
# Out:
# 'e'

# %%
s[4]
# Out:
# 'o'

# %%
len(s)
# Out:
# 7

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
s[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 s[7]
#
# IndexError: string index out of range

# %%
#Backward indexing
s[-1]
# Out:
# 'e'

# %%
s[-3]
# Out:
# 'o'

# %%
s[-5]
# Out:
# 'l'

# %%
s[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 s[-10]
#
# IndexError: string index out of range

# %%
# Slicing concept 
# python[:]  it prints everything
s[:]
# Out:
# 'Welcome'

# %%
# In slicing [L:R]  Right index always implement (n-1) formula
# Left index this (n-1) formula is not applicable
# [2:4] ---print the (value or element) from 2nd index to 4-1 = 3rd index
# [2:6] ---print the (value or element) from 2nd index to 6-1 = 5th index
# [2:] ---Print value from 2nd index till the last
# [:6] ---Print the value  from  0th index till 5th index
# Advanced Slicing -------------> [1:100:10] ---Print the value from every 10th step print the inde
# 1-11-21-31
# [1:100:10]    1 is start index, 100---end index, 10 ---step indexing 
s
# Out:
# 'Welcome'

# %%
s[1:6]    # right index n-1 (6-1)  forward slicing
# Out:
# 'elcom'

# %%
s[2:]
# Out:
# 'lcome'

# %%
s[:7]
# Out:
# 'Welcome'

# %%
s[:10000]
# Out:
# 'Welcome'

# %%
s[1000:]
# Out:
# ''

# %%
s[:10000]
# Out:
# 'Welcome'

# %%
s
# Out:
# 'Welcome'

# %%
s[-1:]
# Out:
# 'e'

# %%
s[-6:]
# Out:
# 'elcome'

# %%
s[-7:-4]      # backward slicing
# Out:
# 'Wel'
