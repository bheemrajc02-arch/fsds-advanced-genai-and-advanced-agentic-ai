# %%
Packages and Libraries

# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
x = math.sqrt(25)
x
# Out:
# 5.0

# %%
round(x)
# Out:
# 5

# %%
floor(2.3)    # lower 2 and higher 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 floor(2.3)    # lower 2 and higher 3
#
# NameError: name 'floor' is not defined

# %%
math.floor(2.3)
# Out:
# 2

# %%
math.ceil(3.6)
# Out:
# 4

# %%
m.floor(2.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 m.floor(2.5)
#
# NameError: name 'm' is not defined

# %%
import math as m
m.floor(2.3)
# Out:
# 2

# %%
m.ceil(2.3)
# Out:
# 3

# %%
from math import *
print(math.pow(2,3))
print(math.floor(3.4))
print(math.ceil(3.4))
print(math.sqrt(40))
# Out:
# 8.0
# 3
# 4
# 6.324555320336759

# %%
help()
# Out:
# Welcome to Python 3.9's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.9/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
# help>  q
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  '__peg_parser__',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
Hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 Hello
#
# NameError: name 'Hello' is not defined

# %%
x = input()
x
# Out:
#  Hello Bheemraj
# 'Hello Bheemraj'

# %%
x = input()
y = input()
z = x+y
print(z)
# Out:
#  2
#  3
# 23

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x2 = int(input('Enter the 1st number'))
y2 = int(input('Enter the 2nd number'))
z2 = x2+y2
print(z2)
print(type(z2))
# Out:
# Enter the 1st number 10
# Enter the 2nd number 20
# 30
# <class 'int'>

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string hello
# hello

# %%
print(st[0])
# Out:
# h

# %%
print(st[0:2])
# Out:
# he

# %%
print(st[1])
# Out:
# e

# %%
st = input('enter a string')[1]
print(st)
# Out:
# enter a string Bheemraj
# h

# %%
st = input('adhar card last four digits visible')[4]
print(st)
# Out:
# adhar card last four digits visible 225214563875
# 1

# %%
st = input('adhar card last four digits visible')[7:11]
print(st)
# Out:
# adhar card last four digits visible 225214783465
# 8346

# %%
st = input('adhar card last four digits visible')[4:]
print(st)
# Out:
# adhar card last four digits visible 225214783465
# 14783465

# %%
result = input('enter an expre')
print(result)
# Out:
# enter an expre 2+3-10
# 2+3-10

# %%
result = int(input('enter an expre'))
print(result)
# Out:
# enter an expre 2+3-10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 result = int(input('enter an expre'))
#       2 print(result)
#
# ValueError: invalid literal for int() with base 10: '2+3-10'

# %%
result = eval(int(input('enter an expre'))
# Out:
#   Cell In[46], line 1
#     result = eval(int(input('enter an expre'))
#                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
result = eval(input('Enter an expression: '))
print(result)
# Out:
# Enter an expression:  2+3-10
# -5
