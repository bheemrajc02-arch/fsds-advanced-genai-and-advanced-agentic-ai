# %%
#Type Casting == Convert one data type to another data type
# Convert all other datatypes to int 

int(3.5)
# Out:
# 3

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
# We cannot typecast complex to int 
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int(1+2j)
#
# TypeError: can't convert complex to int

# %%
# In Python type casting concept we cannot use two arguments always works with only 1 argument.
int(2.3,5.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # In Python type casting concept we cannot use two arguments always works with only 1 argument.
# ----> 2 int(2.3,5.6)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int('10')     # number String
# Out:
# 10

# %%
int('ten')    # Text String
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int('ten')    # Text String
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
# Testcase1 : while typecasting from (other datatype to int) except(complex,text String, User cannot pass more than 2 arguments)

int('23')
# Out:
# 23

# %%
float(23)
# Out:
# 23.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 float(1+2j)
#
# TypeError: can't convert complex to float

# %%
float(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float(2,3)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float('23')
# Out:
# 23.0

# %%
int('23.4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int('23.4')
#
# ValueError: invalid literal for int() with base 10: '23.4'

# %%
# Test Case2 : While type Casting (Other data type to float) from other datatype to float except(complex,textString,user cannot pass more than 2 arguments)

float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Test Case2 : While type Casting (Other data type to float) from other datatype to float except(complex,textString,user cannot pass more than 2 arguments)
# ----> 3 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
bool(2)
# Out:
# True

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool( )
# Out:
# False

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
# Test Case3 : While type Casting (Other data type to bool) from other datatype to bool ---Every Type casting will work
bool(None)
# Out:
# False

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3,4.5)
# Out:
# (2.3+4.5j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False,False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10,'20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 complex(10,'20')
#
# TypeError: complex() second arg can't be a string

# %%
# Test Case4 : While type Casting (Other data type to complex) from other datatype to complex possible when user cannot pass two arguments as String 
# If user want to pass string argument then it should be only one argument should be string

# %%
str(20)
# Out:
# '20'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
s = str(20)
type(s)
# Out:
# str

# %%
# Test Case5 : While type Casting from other data type ---string(no issue at all)

# %%
# Arithemetic Operator(+,-,*,/,%,%%,**,^
# Assigement operator(=)
#Relational Operator 
# Logical  Operator
# Unary  Operator

# 1. # Arithemetic Operator

x1,y1 = 10,5

x1+y1
# Out:
# 15

# %%
x1*y1
# Out:
# 50

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1**y1
# Out:
# 100000

# %%
x2 = 3
y2 = 3
x2 ** y2
# Out:
# 27

# %%
# Assigement operator(=)
x = 2
x = x+2 # if we want to increament by 2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x +=2       
x                             # Need clarity
# Out:
# 8

# %%
x *= 2             # Need Clarity

# %%
x
# Out:
# 128
